# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,5])
y=np.array([3,7])
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,5])
y=np.array([3,6])
plt.plot(x,y,'o')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([2,4,6,8,10,12])
y=np.array([3,5,7,9,6,14])
plt.scatter(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([2,4,6,8,10,12])
y=np.array([3,5,7,9,6,14])
plt.plot(x,y,marker='o')
plt.show()
